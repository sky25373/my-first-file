# %%
s='munai'

# %%
print(type=s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(type=s)
#
# TypeError: 'type' is an invalid keyword argument for print()

# %%
print(type(s))
# Out:
# <class 'str'>

# %%
type(s)
# Out:
# str

# %%
s[0]
# Out:
# 'm'

# %%
s[4]
# Out:
# 'i'

# %%
s[3]
# Out:
# 'a'

# %%
s[-3]
# Out:
# 'n'

# %%
a='my name is munai'

# %%
a[16]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 a[16]
#
# IndexError: string index out of range

# %%
a[-1]
# Out:
# 'i'

# %%
a[1000]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 a[1000]
#
# IndexError: string index out of range

# %%
a
# Out:
# 'my name is munai'

# %%
x='icss'

# %%
x[3]
# Out:
# 's'

# %%
#ics
print(x)
# Out:
# icss

# %%
x[0:3]
# Out:
# 'ics'

# %%
#x[i in range 3]

# %%
for i in (x[:3]):
    print(i)
# Out:
# i
# c
# s

# %%
for i in (reversed(x)):
    print(i)
# Out:
# s
# s
# c
# i

# %%
x
# Out:
# 'icss'

# %%
x
# Out:
# 'icss'

# %%
x[0:2]
# Out:
# 'ic'

# %%
x[0:4000]
# Out:
# 'icss'

# %%
x[0:452]
# Out:
# 'icss'

# %%
x[300]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 x[300]
#
# IndexError: string index out of range

# %%
x[0:58899999]
# Out:
# 'icss'

# %%
a
# Out:
# 'my name is munai'

# %%
a[0:10]
# Out:
# 'my name is'

# %%
a[0:8]
# Out:
# 'my name '

# %%
a[0:7]
# Out:
# 'my name'

# %%
a[0:10]
# Out:
# 'my name is'

# %%
a[0:10:1]
# Out:
# 'my name is'

# %%
a[0:10:2]
# Out:
# 'm aei'

# %%
x
# Out:
# 'icss'

# %%
x[0:10:2]
# Out:
# 'is'

# %%
x='skylucky'

# %%
#slk
x[0:10:3]
# Out:
# 'slk'

# %%
x[0:10:6]
# Out:
# 'sk'

# %%
x[0:10:6]
# Out:
# 'sk'

# %%
x='avhouijutuidse'
#ad
x
# Out:
# 'avhouijutuidse'

# %%
x[0:15:11]
# Out:
# 'ad'

# %%
b='icss'

# %%
b[-1000]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 b[-1000]
#
# IndexError: string index out of range

# %%
b[-1:-100]
# Out:
# ''

# %%
b
# Out:
# 'icss'

# %%
b[0:1]
# Out:
# 'i'

# %%
b[0:-4:2]
# Out:
# ''

# %%
b
# Out:
# 'icss'

# %%
b[0:-1:2]
# Out:
# 'is'

# %%
b
# Out:
# 'icss'

# %%
b
# Out:
# 'icss'

# %%
b[0:2]
# Out:
# 'ic'

# %%
b[0:-1]
# Out:
# 'ics'

# %%
b

# %%
b[-1:-4:-1]
# Out:
# 'ssc'

# %%
b[0:4:2]
# Out:
# 'is'

# %%
b[0:10]
# Out:
# 'icss'

# %%
b[0:10:1]
# Out:
# 'icss'

# %%
b
# Out:
# 'icss'

# %%
b[-1:-4:2]
# Out:
# ''

# %%
b[-1:-4:-2]
# Out:
# 'sc'

# %%
b[0:-1]
# Out:
# 'ics'

# %%
b='icsk'

# %%
b[0:-1]
# Out:
# 'ics'

# %%
b[0:-1+1]
# Out:
# ''

# %%
b
# Out:
# 'icsk'

# %%
b[-1:-4:-1]
# Out:
# 'ksc'

# %%
b='icskyrzpql'

# %%
len(b)
# Out:
# 10

# %%
b[0:-1:2]
# Out:
# 'isyzq'

# %%
b
# Out:
# 'icskyrzpql'

# %%
b[0:-1]
# Out:
# 'icskyrzpq'

# %%
b
# Out:
# 'icskyrzpql'

# %%
b[::1]
# Out:
# 'icskyrzpql'

# %%
b[::-1]
# Out:
# 'lqpzryksci'

# %%
b[::2]
# Out:
# 'isyzq'

# %%
b[-100:]
# Out:
# 'icskyrzpql'

# %%
b[0:-9]
# Out:
# 'i'

# %%
b[-11]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 b[-11]
#
# IndexError: string index out of range

# %%
b
# Out:
# 'icskyrzpql'

# %%
b='sky'

# %%
b[:-2]
# Out:
# 's'

# %%
b[:-1]
# Out:
# 'sk'

# %%
b[:-2]
# Out:
# 's'

# %%
b[:-3]
# Out:
# ''

# %%
b[-1:]
# Out:
# 'y'

# %%
b[-2:]
# Out:
# 'ky'

# %%
b[-3:]
# Out:
# 'sky'

# %%
b='skywuz'
b[-1:]
# Out:
# 'z'

# %%
b[1:]
# Out:
# 'kywuz'

# %%
b[:1]
# Out:
# 's'

# %%
b[3:]
# Out:
# 'wuz'

# %%
b[:3]
# Out:
# 'sky'

# %%
b
# Out:
# 'skywuz'

# %%
b
# Out:
# 'skywuz'

# %%
b[-1:]
# Out:
# 'z'

# %%
b[-2:]
# Out:
# 'uz'

# %%
b[-4:]
# Out:
# 'ywuz'

# %%
b[-5:]
# Out:
# 'kywuz'

# %%
b[:-1]
# Out:
# 'skywu'

# %%
b[:-3]
# Out:
# 'sky'

# %%
b
# Out:
# 'skywuz'

# %%
b[-3:]
# Out:
# 'wuz'

# %%
b[:-3]
# Out:
# 'sky'

# %%
b
# Out:
# 'skywuz'

# %%
b='guggutyryryf'
b[:-4]
# Out:
# 'guggutyr'

# %%
b[-4:]
# Out:
# 'yryf'

# %%
b[:-6]
# Out:
# 'guggut'

# %%
b[::]
# Out:
# 'guggutyryryf'

# %%
s='ggujgyy'
type(s)
# Out:
# str

# %%
t="67545rydshyfsf"
type(t)
# Out:
# str

# %%
y='uuhg990"
type(y)
# Out:
#   Cell In[3], line 1
#     y='uuhg990"
#       ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s='tyuds5'
s[-2:]
# Out:
# 's5'

# %%
s[1:2]
# Out:
# 'y'

# %%
s[1:3]
# Out:
# 'yu'

# %%
s[0:-4:-5]
# Out:
# ''

# %%
s[-5:-3]
# Out:
# 'yu'

# %%
s
# Out:
# 'tyuds5'

# %%
s[::]
# Out:
# 'tyuds5'

# %%
s[::-1]
# Out:
# '5sduyt'

# %%
#maam -> yes
#lucky -> no

# %%
if s==s[::-1]:
    print('palin')
else:
    print('not')
# Out:
# palin

# %%
s='mam'

# %%
s=input('enter name')
if s==s[::-1]:
    print('palin')
else:
    print('not')
# Out:
# enter name mam
# palin

# %%
s=input("Enter any name ========")
if(s[::]==s[::-1]):
    print("palindrome")
else:
    print("not palindrome")
# Out:
# Enter any name ======== yty
# palindrome

# %%
s
# Out:
# 'yty'

# %%
s*3
# Out:
# 'ytyytyyty'

# %%
s
# Out:
# 'yty'

# %%
s*2
# Out:
# 'ytyyty'

# %%
s+2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 s+2
#
# TypeError: can only concatenate str (not "int") to str

# %%
y='dc'
s+y
# Out:
# 'ytydc'

# %%
s='sd'
s*y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 s='sd'
# ----> 2 s*y
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
s
# Out:
# 'sd'

# %%
s+8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 s+8
#
# TypeError: can only concatenate str (not "int") to str

# %%
s+'8'
# Out:
# 'sd8'

# %%
s*'8'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 s*'8'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
s*'y'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 s*'y'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
a='munaia'
a.find('a')
# Out:
# 3

# %%
a='luckysky'
a.find('y')
# Out:
# 4

# %%
a.find('iy')
# Out:
# -1

# %%
a.find('uii')
# Out:
# -1

# %%
#print first index, -1

# %%
a='skylucky'
a.count('y')
# Out:
# 2

# %%
a.count('l')
# Out:
# 1

# %%
a.count('a')
# Out:
# 0

# %%
#how many charc , otherwise 0

# %%
a='uiooo5788'
a.count('8')
# Out:
# 2

# %%
a='8999'
a.count('9')
# Out:
# 3

# %%
a.count('x')
# Out:
# 0

# %%
l='i am student'

# %%
u=l.split() #convert string to list

# %%
type(u)
# Out:
# list

# %%
#string  all are datatype
#list

# %%
l=[6,9,'m','j',78.9,7+9j]
type(l)
# Out:
# list

# %%
#list can store homo and hatero ..... data

# %%
a='i am working as student'

# %%
a.split('working')
# Out:
# ['i am ', ' as student']

# %%
a
# Out:
# 'i am working as student'

# %%
l=a.split('am')

# %%
l
# Out:
# ['i ', ' working as student']

# %%
a
# Out:
# 'i am working as student'

# %%
l=a.split('wo')

# %%
l
# Out:
# ['i am ', 'rking as student']

# %%
a.split('am')
# Out:
# ['i ', ' working as student']

# %%
a='skylucky'
a.upper()
# Out:
# 'SKYLUCKY'

# %%
l=a.upper()
l
# Out:
# 'SKYLUCKY'

# %%
l
# Out:
# 'SKYLUCKY'

# %%
s='SkY'
s.swapcase()
# Out:
# 'sKy'

# %%
s.title()
# Out:
# 'Sky'

# %%
s
# Out:
# 'SkY'

# %%
s='luckysky'

# %%
s.title()
# Out:
# 'Luckysky'

# %%
s='sky'
s.title()
# Out:
# 'Sky'

# %%
s.capitalize()
# Out:
# 'Sky'

# %%
b='sky'
c='lucky'
b.join(c)
# Out:
# 'lskyuskycskykskyy'

# %%
"  ".join('sky')
# Out:
# 's  k  y'

# %%
s=' sky@ '
s.lstrip()
# Out:
# 'sky@ '

# %%
s.rstrip('s')
# Out:
# ' sky@ '

# %%
s
# Out:
# ' sky@ '

# %%
s
# Out:
# ' sky@ '

# %%
s.strip()
# Out:
# 'sky@'

# %%
s.strip(' ')
# Out:
# 'sky@'

# %%
s.strip('')
# Out:
# ' sky@ '

# %%
s.strip()
# Out:
# 'sky@'

# %%
s.strip('a ')
# Out:
# 'sky@'

# %%
s.strip()
# Out:
# 'sky@'

# %%
s
# Out:
# ' sky@ '

# %%
s.replace('@','lucky')
# Out:
# ' skylucky '

# %%
s.replace('@','')
# Out:
# ' sky '

# %%
s.center(10,'#')
# Out:
# '## sky@ ##'

# %%
s='sky'

# %%
s.center(5,'#')
# Out:
# '#sky#'

# %%
s.center(2,'#')
# Out:
# 'sky'

# %%
s.center(19,'#')
# Out:
# '########sky########'

# %%
s.isupper()
# Out:
# False

# %%
s
# Out:
# 'sky'

# %%
s.islower()
# Out:
# True

# %%
s='Sky'
s.islower()
# Out:
# False

# %%
s.isupper()
# Out:
# False

# %%
s='SKY'
s.isupper()
# Out:
# True

# %%
s.isspace()
# Out:
# False

# %%
s='sky '
s.isspace()
# Out:
# False

# %%
s=' '
s.isspace()
# Out:
# True

# %%
s=' sky '
s.isspace()
# Out:
# False

# %%
s='56y5yyytytytyt'
s.isdigit()
# Out:
# False

# %%
s='4335'
s.isdigit()
# Out:
# True
